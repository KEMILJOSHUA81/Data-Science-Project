# %%
import pandas as pd;

# %%
media = pd.read_csv('C:/Users/emilj/OneDrive/Desktop/python Project/KEJ/archive (2)/Viral_Social_Media_Trends.csv')

# %%
media_copy = media.copy()

# %%
media
# Out:
#         Post_ID   Platform     Hashtag Content_Type     Region    Views  \
# 0        Post_1     TikTok  #Challenge        Video         UK  4163464
# 1        Post_2  Instagram  #Education       Shorts      India  4155940
# 2        Post_3    Twitter  #Challenge        Video     Brazil  3666211
# 3        Post_4    YouTube  #Education       Shorts  Australia   917951
# 4        Post_5     TikTok      #Dance         Post     Brazil    64866
# ...         ...        ...         ...          ...        ...      ...
# 4995  Post_4996    YouTube  #Education        Video      Japan  4258236
# 4996  Post_4997  Instagram  #Education        Video         UK  4841525
# 4997  Post_4998    YouTube    #Fashion       Shorts        USA  2004080
# 4998  Post_4999  Instagram     #Gaming       Shorts     Canada  2221665
# 4999  Post_5000  Instagram    #Fashion         Reel      Japan  2224007
#
#        Likes  Shares  Comments Engagement_Level
# 0     339431   53135     19346             High
# ...

# %%
media.loc[234]
# Out:
# Post_ID             Post_235
# Platform             YouTube
# Hashtag               #Viral
# Content_Type            Reel
# Region                 Japan
# Views                1715566
# Likes                 326676
# Shares                 69635
# Comments               19235
# Engagement_Level         Low
# Name: 234, dtype: object

# %%
type(media.loc[234])
# Out:
# pandas.core.series.Series

# %%
media.head(5)
# Out:
#   Post_ID   Platform     Hashtag Content_Type     Region    Views   Likes  \
# 0  Post_1     TikTok  #Challenge        Video         UK  4163464  339431
# 1  Post_2  Instagram  #Education       Shorts      India  4155940  215240
# 2  Post_3    Twitter  #Challenge        Video     Brazil  3666211  327143
# 3  Post_4    YouTube  #Education       Shorts  Australia   917951  127125
# 4  Post_5     TikTok      #Dance         Post     Brazil    64866  171361
#
#    Shares  Comments Engagement_Level
# 0   53135     19346             High
# 1   65860     27239           Medium
# 2   39423     36223           Medium
# 3   11687     36806              Low
# 4   69581      6376           Medium

# %%
media.tail(4)
# Out:
#         Post_ID   Platform     Hashtag Content_Type  Region    Views   Likes  \
# 4996  Post_4997  Instagram  #Education        Video      UK  4841525  166266
# 4997  Post_4998    YouTube    #Fashion       Shorts     USA  2004080   32401
# 4998  Post_4999  Instagram     #Gaming       Shorts  Canada  2221665   46996
# 4999  Post_5000  Instagram    #Fashion         Reel   Japan  2224007   72744
#
#       Shares  Comments Engagement_Level
# 4996   54841      4832           Medium
# 4997   75229     33875              Low
# 4998   12954     42832              Low
# 4999   29945     46381              Low

# %%
media.sample(10)
# Out:
#         Post_ID   Platform     Hashtag Content_Type     Region    Views  \
# 511    Post_512     TikTok      #Music         Post         UK  4038519
# 4396  Post_4397     TikTok    #Fashion        Tweet      India   582999
# 828    Post_829    YouTube    #Fashion         Post      Japan  4586518
# 2505  Post_2506    Twitter  #Challenge  Live Stream     Brazil  1557528
# 2368  Post_2369  Instagram      #Viral        Video      Japan  4530657
# 4873  Post_4874  Instagram    #Fitness        Video      Japan  2758867
# 4767  Post_4768    YouTube      #Dance        Video  Australia  2618299
# 233    Post_234    YouTube  #Education       Shorts        USA  1465227
# 4113  Post_4114  Instagram      #Music  Live Stream     Brazil  3042134
# 913    Post_914    Twitter    #Fitness       Shorts     Brazil  4741739
#
#        Likes  Shares  Comments Engagement_Level
# 511   320781   72443     16822             High
# 4396  200303    2292     45395             High
# ...

# %%
media.shape
# Out:
# (5000, 10)
